# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1],[1])

# %%
plt.plot([1,1.5,2],[1,2,1])

# %%
plt.plot([0,1,2],[1,2,1],[1,1,1])

# %%
plt.plot([0,1,1],[0,0,1],[0,0,1],[0,1,1])

# %%
plt.plot([0,1,2],[1,2,1],[1,1,1])
plt.plot([0,1,1],[0,0,1],[0,0,1],[0,1,1])
