# %% [markdown]
# ## UNIVERSIDAD AUTONOMA DEL ESTADO DE MEXICO
#
# # INGENIERIA EN COMPUTACION
#
# RAUL ALEJANDRO CALDERON HERNANDEZ
#
# GRAFICACION COMPUTACIONAL
#
# 30 DE SEPTIEMBRE DEL 2024
#
# Examen primer parcial

# %% [markdown]
# vemos la imagen principal de la figura, que es la siguiente: donde observamos sus 15 vertices, y en teoria deben contener los 13 triangulos
# ![Imagen1.jpg](attachment:1a814362-dcc5-43ef-b952-1bf202cb9a1a.jpg)

# %%
import numpy as np
import matplotlib.pyplot as plt
#importamos

# %%
#
x1 = -40
x2 = 40

y1= 40
y2 = -40

plt.axis([x1,x2,y2,y1])
plt.axis("on")
plt.grid(True)
#creamos el plano 
plt.arrow(10.2,30,-14.5,1)
plt.arrow(10,30,-3.5,-20)
plt.arrow(7,10,15,5)
plt.arrow(22,15,-5,-20)
plt.arrow(17,-5,5,-10)
plt.arrow(22,-15,-10,-10)
plt.arrow(12,-25,-25,5)
plt.arrow(-13,-20,8,8)
plt.arrow(-15,-9,10,-3)
plt.arrow(-15,-9,-5,-5)
plt.arrow(-20,-14,-10,10)
plt.arrow(-30,-4,5,10)
plt.arrow(-25,6,-5,10)
plt.arrow(-30,16,23.4,2)
plt.arrow(-7,18,2.5,13)
#graficamos los vectores, con los valores que posiblemente tengan
plt.title("Figura")
# Out:
# Text(0.5, 1.0, 'Figura')

# %% [markdown]
# Creamos la figura que observamos en el ejercicio anterior, donde podemos ver los posibles vertices que contiene, por ejemplo tiene 15 vertices, entonces por medio de la formula, nos quedaria
# n-2 en ese caso N serian 15 y menos 2 quedaria en 13 triangulos

# %%
x1 = -40
x2 = 40

y1= 40
y2 = -40

plt.axis([x1,x2,y2,y1])
plt.axis("on")
plt.grid(True)
#creamos el plano 
plt.arrow(10.2,30,-14.5,1)
plt.arrow(10,30,-3.5,-20)
plt.arrow(7,10,15,5)
plt.arrow(22,15,-5,-20)
plt.arrow(17,-5,5,-10)
plt.arrow(22,-15,-10,-10)
plt.arrow(12,-25,-25,5)
plt.arrow(-13,-20,8,8)
plt.arrow(-15,-9,10,-3)
plt.arrow(-15,-9,-5,-5)
plt.arrow(-20,-14,-10,10)
plt.arrow(-30,-4,5,10)
plt.arrow(-25,6,-5,10)
plt.arrow(-30,16,23.4,2)
plt.arrow(-7,18,2.5,13)
#graficamos los vectores, con los valores que posiblemente tengan



#graficamos los triangulos 
plt.fill([-7,9.76,6.5],[18,30,10], color='blue')  # AZUL
#GRAFICAMOS EL TRIANGULO, azul el primer triangulo 
plt.title("Figura")
# Out:
# Text(0.5, 1.0, 'Figura')

# %% [markdown]
# vemos como el metodo de graficacion de la figura nos demuestra como el triangulo azul es el primero en ser graficado

# %%
x1 = -40
x2 = 40
y1= 40
y2 = -40
plt.axis([x1,x2,y2,y1])
plt.axis("on")
plt.grid(True)
#creamos el plano 
plt.arrow(10.2,30,-14.5,1)
plt.arrow(10,30,-3.5,-20)
plt.arrow(7,10,15,5)
plt.arrow(22,15,-5,-20)
plt.arrow(17,-5,5,-10)
plt.arrow(22,-15,-10,-10)
plt.arrow(12,-25,-25,5)
plt.arrow(-13,-20,8,8)
plt.arrow(-15,-9,10,-3)
plt.arrow(-15,-9,-5,-5)
plt.arrow(-20,-14,-10,10)
plt.arrow(-30,-4,5,10)
plt.arrow(-25,6,-5,10)
plt.arrow(-30,16,23.4,2)
plt.arrow(-7,18,2.5,13)
#graficamos los vectores, con los valores que posiblemente tengan



#graficamos los triangulos 

plt.fill([-7,-4.5,10],[18,31,30], color='red')  # rojo
#GRAFICAMOS EL TRIANGULO, rojo el segundo triangulo 
plt.title("Figura")
# Out:
# Text(0.5, 1.0, 'Figura')

# %%
x1 = -40
x2 = 40

y1= 40
y2 = -40
plt.axis([x1,x2,y2,y1])
plt.axis("on")
plt.grid(True)
#creamos el plano 
plt.arrow(10.2,30,-14.5,1)
plt.arrow(10,30,-3.5,-20)
plt.arrow(7,10,15,5)
plt.arrow(22,15,-5,-20)
plt.arrow(17,-5,5,-10)
plt.arrow(22,-15,-10,-10)
plt.arrow(12,-25,-25,5)
plt.arrow(-13,-20,8,8)
plt.arrow(-15,-9,10,-3)
plt.arrow(-15,-9,-5,-5)
plt.arrow(-20,-14,-10,10)
plt.arrow(-30,-4,5,10)
plt.arrow(-25,6,-5,10)
plt.arrow(-30,16,23.4,2)
plt.arrow(-7,18,2.5,13)
#graficamos los vectores, con los valores que posiblemente tenga la figura, observando que todos los valores se pueden graficar



#graficamos los triangulos 
plt.fill([7,22,17],[10,15,-5], color='green')  # verde
#graficamos el tercer triangulo de color verde
plt.title("Figura")
# Out:
# Text(0.5, 1.0, 'Figura')

# %%
x1 = -40
x2 = 40

y1= 40
y2 = -40
plt.axis([x1,x2,y2,y1])
plt.axis("on")
plt.grid(True)
#creamos el plano 
plt.arrow(10.2,30,-14.5,1)
plt.arrow(10,30,-3.5,-20)
plt.arrow(7,10,15,5)
plt.arrow(22,15,-5,-20)
plt.arrow(17,-5,5,-10)
plt.arrow(22,-15,-10,-10)
plt.arrow(12,-25,-25,5)
plt.arrow(-13,-20,8,8)
plt.arrow(-15,-9,10,-3)
plt.arrow(-15,-9,-5,-5)
plt.arrow(-20,-14,-10,10)
plt.arrow(-30,-4,5,10)
plt.arrow(-25,6,-5,10)
plt.arrow(-30,16,23.4,2)
plt.arrow(-7,18,2.5,13)
#graficamos los vectores, con los valores que posiblemente tenga la figura 

#graficamos los triangulos 
plt.fill([17,22,12],[-5,-15,-25], color='black')  # negro
#GRAFICAMOS EL TRIANGULO, verde el cuarto triangulo 
plt.title("Figura")
# Out:
# Text(0.5, 1.0, 'Figura')

# %%
x1 = -40
x2 = 40

y1= 40
y2 = -40
plt.axis([x1,x2,y2,y1])
plt.axis("on")
plt.grid(True)
#creamos el plano 
plt.arrow(10.2,30,-14.5,1)
plt.arrow(10,30,-3.5,-20)
plt.arrow(7,10,15,5)
plt.arrow(22,15,-5,-20)
plt.arrow(17,-5,5,-10)
plt.arrow(22,-15,-10,-10)
plt.arrow(12,-25,-25,5)
plt.arrow(-13,-20,8,8)
plt.arrow(-15,-9,10,-3)
plt.arrow(-15,-9,-5,-5)
plt.arrow(-20,-14,-10,10)
plt.arrow(-30,-4,5,10)
plt.arrow(-25,6,-5,10)
plt.arrow(-30,16,23.4,2)
plt.arrow(-7,18,2.5,13)
#graficamos los vectores, con los valores que posiblemente tengan



#graficamos los triangulos 

plt.fill([-15,-5,12],[-20,-12,-25], color='green')  # verde
#GRAFICAMOS EL TRIANGULO, verde el quinto triangulo 
plt.title("Figura")
# Out:
# Text(0.5, 1.0, 'Figura')

# %%
x1 = -40
x2 = 40

y1= 40
y2 = -40
plt.axis([x1,x2,y2,y1])
plt.axis("on")
plt.grid(True)
#creamos el plano 
plt.arrow(10.2,30,-14.5,1)
plt.arrow(10,30,-3.5,-20)
plt.arrow(7,10,15,5)
plt.arrow(22,15,-5,-20)
plt.arrow(17,-5,5,-10)
plt.arrow(22,-15,-10,-10)
plt.arrow(12,-25,-25,5)
plt.arrow(-13,-20,8,8)
plt.arrow(-15,-9,10,-3)
plt.arrow(-15,-9,-5,-5)
plt.arrow(-20,-14,-10,10)
plt.arrow(-30,-4,5,10)
plt.arrow(-25,6,-5,10)
plt.arrow(-30,16,23.4,2)
plt.arrow(-7,18,2.5,13)
#graficamos los vectores, con los valores que posiblemente tengan



#graficamos los triangulos 

plt.fill([-5,12,17],[-12,-25,-5], color='pink')  #rosa 
#GRAFICAMOS EL TRIANGULO, rosa el sexto triangulo 
plt.title("Figura")
# Out:
# Text(0.5, 1.0, 'Figura')

# %%
x1 = -40
x2 = 40

y1= 40
y2 = -40


plt.axis([x1,x2,y2,y1])
plt.axis("on")
plt.grid(True)
#creamos el plano 
plt.arrow(10.2,30,-14.5,1)
plt.arrow(10,30,-3.5,-20)
plt.arrow(7,10,15,5)
plt.arrow(22,15,-5,-20)
plt.arrow(17,-5,5,-10)
plt.arrow(22,-15,-10,-10)
plt.arrow(12,-25,-25,5)
plt.arrow(-13,-20,8,8)
plt.arrow(-15,-9,10,-3)
plt.arrow(-15,-9,-5,-5)
plt.arrow(-20,-14,-10,10)
plt.arrow(-30,-4,5,10)
plt.arrow(-25,6,-5,10)
plt.arrow(-30,16,23.4,2)
plt.arrow(-7,18,2.5,13)
#graficamos los vectores, con los valores que posiblemente tengan



#graficamos los triangulos 
plt.fill([-15,7,-5],[-9,10,-12], color='skyblue') #azul claro 
#GRAFICAMOS EL TRIANGULO, azul caro el septimo triangulo 
plt.title("Figura")
# Out:
# Text(0.5, 1.0, 'Figura')

# %%
x1 = -40
x2 = 40

y1= 40
y2 = -40


plt.axis([x1,x2,y2,y1])
plt.axis("on")
plt.grid(True)
#creamos el plano 
plt.arrow(10.2,30,-14.5,1)
plt.arrow(10,30,-3.5,-20)
plt.arrow(7,10,15,5)
plt.arrow(22,15,-5,-20)
plt.arrow(17,-5,5,-10)
plt.arrow(22,-15,-10,-10)
plt.arrow(12,-25,-25,5)
plt.arrow(-13,-20,8,8)
plt.arrow(-15,-9,10,-3)
plt.arrow(-15,-9,-5,-5)
plt.arrow(-20,-14,-10,10)
plt.arrow(-30,-4,5,10)
plt.arrow(-25,6,-5,10)
plt.arrow(-30,16,23.4,2)
plt.arrow(-7,18,2.5,13)
#graficamos los vectores, con los valores que posiblemente tengan



#graficamos los triangulos 

plt.fill([-5,7,17],[-12,10,-5], color='orange')  # naranja
#GRAFICAMOS EL TRIANGULO, naranja el octavo triangulo 
plt.title("Figura")
# Out:
# Text(0.5, 1.0, 'Figura')

# %%
x1 = -40
x2 = 40

y1= 40
y2 = -40

plt.axis([x1,x2,y2,y1])
plt.axis("on")
plt.grid(True)
#creamos el plano 
plt.arrow(10.2,30,-14.5,1)
plt.arrow(10,30,-3.5,-20)
plt.arrow(7,10,15,5)
plt.arrow(22,15,-5,-20)
plt.arrow(17,-5,5,-10)
plt.arrow(22,-15,-10,-10)
plt.arrow(12,-25,-25,5)
plt.arrow(-13,-20,8,8)
plt.arrow(-15,-9,10,-3)
plt.arrow(-15,-9,-5,-5)
plt.arrow(-20,-14,-10,10)
plt.arrow(-30,-4,5,10)
plt.arrow(-25,6,-5,10)
plt.arrow(-30,16,23.4,2)
plt.arrow(-7,18,2.5,13)
#graficamos los vectores, con los valores que posiblemente tengan



#graficamos los triangulos 



plt.fill([-30,-25,-20],[-4,6,-14], color='purple')  # Morado
#GRAFICAMOS EL TRIANGULO, rojo el noveno triangulo 
plt.title("Figura")
# Out:
# Text(0.5, 1.0, 'Figura')

# %%
x1 = -40
x2 = 40

y1= 40
y2 = -40


plt.axis([x1,x2,y2,y1])
plt.axis("on")
plt.grid(True)
#creamos el plano 
plt.arrow(10.2,30,-14.5,1)
plt.arrow(10,30,-3.5,-20)
plt.arrow(7,10,15,5)
plt.arrow(22,15,-5,-20)
plt.arrow(17,-5,5,-10)
plt.arrow(22,-15,-10,-10)
plt.arrow(12,-25,-25,5)
plt.arrow(-13,-20,8,8)
plt.arrow(-15,-9,10,-3)
plt.arrow(-15,-9,-5,-5)
plt.arrow(-20,-14,-10,10)
plt.arrow(-30,-4,5,10)
plt.arrow(-25,6,-5,10)
plt.arrow(-30,16,23.4,2)
plt.arrow(-7,18,2.5,13)
#graficamos los vectores, con los valores que posiblemente tengan



#graficamos los triangulos 

plt.fill([-25,-20,-15],[6,-14,-9], color='yellow')  # amarillo
#GRAFICAMOS EL TRIANGULO, amarillo el decimo triangulo 
plt.title("Figura")
# Out:
# Text(0.5, 1.0, 'Figura')

# %%
x1 = -40
x2 = 40

y1= 40
y2 = -40

plt.axis([x1,x2,y2,y1])
plt.axis("on")
plt.grid(True)
#creamos el plano 
plt.arrow(10.2,30,-14.5,1)
plt.arrow(10,30,-3.5,-20)
plt.arrow(7,10,15,5)
plt.arrow(22,15,-5,-20)
plt.arrow(17,-5,5,-10)
plt.arrow(22,-15,-10,-10)
plt.arrow(12,-25,-25,5)
plt.arrow(-13,-20,8,8)
plt.arrow(-15,-9,10,-3)
plt.arrow(-15,-9,-5,-5)
plt.arrow(-20,-14,-10,10)
plt.arrow(-30,-4,5,10)
plt.arrow(-25,6,-5,10)
plt.arrow(-30,16,23.4,2)
plt.arrow(-7,18,2.5,13)
#graficamos los vectores, con los valores que posiblemente tengan



#graficamos los triangulos 
plt.fill([-30,-6,-25],[16,18,6], color='brown')  #cafe
#GRAFICAMOS EL TRIANGULO, cafe el onceavo triangulo 
plt.title("Figura")
# Out:
# Text(0.5, 1.0, 'Figura')

# %%
x1 = -40
x2 = 40

y1= 40
y2 = -40

plt.axis([x1,x2,y2,y1])
plt.axis("on")
plt.grid(True)
#creamos el plano 
plt.arrow(10.2,30,-14.5,1)
plt.arrow(10,30,-3.5,-20)
plt.arrow(7,10,15,5)
plt.arrow(22,15,-5,-20)
plt.arrow(17,-5,5,-10)
plt.arrow(22,-15,-10,-10)
plt.arrow(12,-25,-25,5)
plt.arrow(-13,-20,8,8)
plt.arrow(-15,-9,10,-3)
plt.arrow(-15,-9,-5,-5)
plt.arrow(-20,-14,-10,10)
plt.arrow(-30,-4,5,10)
plt.arrow(-25,6,-5,10)
plt.arrow(-30,16,23.4,2)
plt.arrow(-7,18,2.5,13)
#graficamos los vectores, con los valores que posiblemente tengan



#graficamos los triangulos 

plt.fill([-25,-6,7],[6,18,10], color='gray')  #gris
#GRAFICAMOS EL TRIANGULO, gris el doceavo triangulo 
plt.title("Figura")
# Out:
# Text(0.5, 1.0, 'Figura')

# %%
x1 = -40
x2 = 40

y1= 40
y2 = -40

plt.axis([x1,x2,y2,y1])
plt.axis("on")
plt.grid(True)
#creamos el plano 
plt.arrow(10.2,30,-14.5,1)
plt.arrow(10,30,-3.5,-20)
plt.arrow(7,10,15,5)
plt.arrow(22,15,-5,-20)
plt.arrow(17,-5,5,-10)
plt.arrow(22,-15,-10,-10)
plt.arrow(12,-25,-25,5)
plt.arrow(-13,-20,8,8)
plt.arrow(-15,-9,10,-3)
plt.arrow(-15,-9,-5,-5)
plt.arrow(-20,-14,-10,10)
plt.arrow(-30,-4,5,10)
plt.arrow(-25,6,-5,10)
plt.arrow(-30,16,23.4,2)
plt.arrow(-7,18,2.5,13)
#graficamos los vectores, con los valores que posiblemente tengan
plt.fill([-7,9.76,7],[18,30,10], color='blue')  # AZUL
plt.fill([-25,-7,7],[6,18,10], color='gray')  #gris
plt.fill([-30,-7,-25],[16,18,6], color='brown')  #cafe
plt.fill([-25,-20,-15],[6,-14,-9], color='yellow')  # amarillo
plt.fill([-30,-25,-20],[-4,6,-14], color='purple')  # morado
plt.fill([-5,7,17],[-12,10,-5], color='orange')  # naranja
plt.fill([-15,7,-5],[-9,10,-12], color='skyblue') #azul claro 
plt.fill([-5,12,17],[-12,-25,-5], color='pink')   #rosa
plt.fill([-15,-5,12],[-20,-12,-25], color='green')  # verde 
plt.fill([7,22,17],[10,15,-5], color='green')  # verde
plt.fill([-7,-4.5,10],[18,31,30], color='red')  # rojo 
plt.fill([17,22,12],[-5,-15,-25], color='black')  # negro

# %% [markdown]
# Observamos que si juntamos los triangulos se junta el treceavo triangulo aparece de color blanco, donde
# 1. rojo
# 2. azul
# 3. verde
# 4. negro
# 5. rosa
# 6. verde
# 7. naranja
# 8. azul claro
# 9. amarillo
# 10. morado
# 11. cafe
# 12. gris
# 13. blanco
# Entonces la formula se comprueba, quedando asi toda la figura completa y rellenada de colores diferentes
# vemos como al graficar los triangulos, podemos observar que necesitamos los puntos de los vertices donde queremos que los triangulos aparezcan, si alteramos los valores pues modificaria, el triangulo de otra forma diferente
# le dimos a todos los triangulos la figura inicial, e ibamos marcando el triangulo uno a uno, al final verificamos que se cumple el teorema de los triangulos con la figura inicial, vemos que son 13 triangulos, y contiene 15 vertices
