# %% [markdown]
# ## UNIVERSIDAD AUTONOMA DEL ESTADO DE MEXICO
#
# # INGENIERIA EN COMPUTACION
#
# RAUL ALEJANDRO CALDERON HERNANDEZ
#
# GRAFICACION COMPUTACIONAL
#
# 30 DE SEPTIEMBRE DEL 2024
#
# Examen primer parcial

# %%
import numpy as np
import matplotlib.pyplot as plt
#importamos

# %%
x1 = -40
x2 = 40

y1= 40
y2 = -40

plt.axis([x1,x2,y2,y1])
#creamos el plano 
plt.arrow(10.2,30,-20,1,head_length=0,head_width=0,color="#f3243c")
plt.arrow(10,30,-8,-20,color="b")
plt.arrow(2,10,20,5,color="g")
plt.arrow(22,15,-5,-20)
plt.arrow(17,-5,5,-10,color= "r")
plt.arrow(22,-15,-10,-10,color= "g")
plt.arrow(12,-25,-25,5,color= "b")
plt.arrow(-13,-20,8,8)
plt.arrow(-15,-9,10,-3,color= "g")
plt.arrow(-15,-9,-5,-5,color= "b")
plt.arrow(-20,-14,-10,10)
plt.arrow(-30,-4,5,10,color= "g")
plt.arrow(-25,6,-5,10,color= "b")
plt.arrow(-30,16,18,2,color = "r")
plt.arrow(-12,18,2.5,13)
#graficamos los vectores, con los valores que posiblemente tengan
plt.title("Figura")
# Out:
# Text(0.5, 1.0, 'Figura')

# %%
x1 = -40
x2 = 40

y1= 40
y2 = -40

plt.axis([x1,x2,y2,y1])

plt.arrow(10.2,30,-20,1,head_length=0,head_width=0,color="#f3243c")
#agregamos el primer vector

# %%
x1 = -40
x2 = 40

y1= 40
y2 = -40

plt.axis([x1,x2,y2,y1])

plt.arrow(10.2,30,-20,1,head_length=0,head_width=0,color="#f3243c")

plt.arrow(10,30,-8,-20,color="b")
#agregamos el segundo vector, conforme al primero

# %%
x1 = -40
x2 = 40

y1= 40
y2 = -40

plt.axis([x1,x2,y2,y1])

plt.arrow(10.2,30,-20,1,head_length=0,head_width=0,color="#f3243c")

plt.arrow(10,30,-8,-20,color="b")
plt.arrow(2,10,20,5,color="g")
#sucesivamente, el vector con los vectores anteriores

# %%
x1 = -40
x2 = 40

y1= 40
y2 = -40

plt.axis([x1,x2,y2,y1])

plt.arrow(10.2,30,-20,1,head_length=0,head_width=0,color="#f3243c")

plt.arrow(10,30,-8,-20,color="b")
plt.arrow(2,10,20,5,color="g")

plt.arrow(22,15,-5,-20)
#este es el nuevo vector, copiamos los anteriores

# %%
x1 = -40
x2 = 40

y1= 40
y2 = -40

plt.axis([x1,x2,y2,y1])

plt.arrow(10.2,30,-20,1,head_length=0,head_width=0,color="#f3243c")

plt.arrow(10,30,-8,-20,color="b")
plt.arrow(2,10,20,5,color="g")

plt.arrow(22,15,-5,-20)

plt.arrow(17,-5,5,-10,color= "r")
#cada nuevo vector trae los anteriores

# %%
x1 = -40
x2 = 40

y1= 40
y2 = -40

plt.axis([x1,x2,y2,y1])

plt.arrow(10.2,30,-20,1,head_length=0,head_width=0,color="#f3243c")

plt.arrow(10,30,-8,-20,color="b")
plt.arrow(2,10,20,5,color="g")

plt.arrow(22,15,-5,-20)

plt.arrow(17,-5,5,-10,color= "r")

plt.arrow(22,-15,-10,-10,color= "g")
#despues el otro

# %%
x1 = -40
x2 = 40

y1= 40
y2 = -40

plt.axis([x1,x2,y2,y1])

plt.arrow(10.2,30,-20,1,head_length=0,head_width=0,color="#f3243c")

plt.arrow(10,30,-8,-20,color="b")
plt.arrow(2,10,20,5,color="g")

plt.arrow(22,15,-5,-20)

plt.arrow(17,-5,5,-10,color= "r")

plt.arrow(22,-15,-10,-10,color= "g")

plt.arrow(12,-25,-25,5,color= "b")
#este es el nuevo vector

# %%
x1 = -40
x2 = 40

y1= 40
y2 = -40

plt.axis([x1,x2,y2,y1])

plt.arrow(10.2,30,-20,1,head_length=0,head_width=0,color="#f3243c")

plt.arrow(10,30,-8,-20,color="b")
plt.arrow(2,10,20,5,color="g")

plt.arrow(22,15,-5,-20)

plt.arrow(17,-5,5,-10,color= "r")

plt.arrow(22,-15,-10,-10,color= "g")

plt.arrow(12,-25,-25,5,color= "b")

plt.arrow(-13,-20,8,8)
#este es el nuevo vector, trayendo los anteriores

# %%
x1 = -40
x2 = 40

y1= 40
y2 = -40

plt.axis([x1,x2,y2,y1])

plt.arrow(10.2,30,-20,1,head_length=0,head_width=0,color="#f3243c")

plt.arrow(10,30,-8,-20,color="b")
plt.arrow(2,10,20,5,color="g")

plt.arrow(22,15,-5,-20)

plt.arrow(17,-5,5,-10,color= "r")

plt.arrow(22,-15,-10,-10,color= "g")

plt.arrow(12,-25,-25,5,color= "b")

plt.arrow(-13,-20,8,8)

plt.arrow(-15,-9,10,-3,color= "g")
#este es el nuevo vector con los vectores anteriores

# %%
x1 = -40
x2 = 40

y1= 40
y2 = -40

plt.axis([x1,x2,y2,y1])

plt.arrow(10.2,30,-20,1,head_length=0,head_width=0,color="#f3243c")

plt.arrow(10,30,-8,-20,color="b")
plt.arrow(2,10,20,5,color="g")

plt.arrow(22,15,-5,-20)

plt.arrow(17,-5,5,-10,color= "r")

plt.arrow(22,-15,-10,-10,color= "g")

plt.arrow(12,-25,-25,5,color= "b")

plt.arrow(-13,-20,8,8)

plt.arrow(-15,-9,10,-3,color= "g")

plt.arrow(-15,-9,-5,-5,color= "b")
#nuevo vector con los vectores anteriores

# %%
x1 = -40
x2 = 40

y1= 40
y2 = -40

plt.axis([x1,x2,y2,y1])

plt.arrow(10.2,30,-20,1,head_length=0,head_width=0,color="#f3243c")

plt.arrow(10,30,-8,-20,color="b")
plt.arrow(2,10,20,5,color="g")

plt.arrow(22,15,-5,-20)

plt.arrow(17,-5,5,-10,color= "r")

plt.arrow(22,-15,-10,-10,color= "g")

plt.arrow(12,-25,-25,5,color= "b")

plt.arrow(-13,-20,8,8)

plt.arrow(-15,-9,10,-3,color= "g")

plt.arrow(-15,-9,-5,-5,color= "b")

plt.arrow(-20,-14,-10,10)
x1 = -40
x2 = 40

y1= 40
y2 = -40

plt.axis([x1,x2,y2,y1])

plt.arrow(10.2,30,-20,1,head_length=0,head_width=0,color="#f3243c")

plt.arrow(10,30,-8,-20,color="b")
plt.arrow(2,10,20,5,color="g")

plt.arrow(22,15,-5,-20)

plt.arrow(17,-5,5,-10,color= "r")

plt.arrow(22,-15,-10,-10,color= "g")

plt.arrow(12,-25,-25,5,color= "b")

plt.arrow(-13,-20,8,8)

plt.arrow(-15,-9,10,-3,color= "g")

plt.arrow(-15,-9,-5,-5,color= "b")

plt.arrow(-20,-14,-10,10)

# %%
x1 = -40
x2 = 40

y1= 40
y2 = -40

plt.axis([x1,x2,y2,y1])

plt.arrow(10.2,30,-20,1,head_length=0,head_width=0,color="#f3243c")

plt.arrow(10,30,-8,-20,color="b")
plt.arrow(2,10,20,5,color="g")

plt.arrow(22,15,-5,-20)

plt.arrow(17,-5,5,-10,color= "r")

plt.arrow(22,-15,-10,-10,color= "g")

plt.arrow(12,-25,-25,5,color= "b")

plt.arrow(-13,-20,8,8)

plt.arrow(-15,-9,10,-3,color= "g")

plt.arrow(-15,-9,-5,-5,color= "b")

plt.arrow(-20,-14,-10,10)
x1 = -40
x2 = 40

y1= 40
y2 = -40

plt.axis([x1,x2,y2,y1])

plt.arrow(10.2,30,-20,1,head_length=0,head_width=0,color="#f3243c")

plt.arrow(10,30,-8,-20,color="b")
plt.arrow(2,10,20,5,color="g")

plt.arrow(22,15,-5,-20)

plt.arrow(17,-5,5,-10,color= "r")

plt.arrow(22,-15,-10,-10,color= "g")

plt.arrow(12,-25,-25,5,color= "b")

plt.arrow(-13,-20,8,8)

plt.arrow(-15,-9,10,-3,color= "g")

plt.arrow(-15,-9,-5,-5,color= "b")

plt.arrow(-20,-14,-10,10)

plt.arrow(-30,-4,5,10,color= "g")

# %%
x1 = -40
x2 = 40

y1= 40
y2 = -40

plt.axis([x1,x2,y2,y1])

plt.arrow(10.2,30,-20,1,head_length=0,head_width=0,color="#f3243c")

plt.arrow(10,30,-8,-20,color="b")
plt.arrow(2,10,20,5,color="g")

plt.arrow(22,15,-5,-20)

plt.arrow(17,-5,5,-10,color= "r")

plt.arrow(22,-15,-10,-10,color= "g")

plt.arrow(12,-25,-25,5,color= "b")

plt.arrow(-13,-20,8,8)

plt.arrow(-15,-9,10,-3,color= "g")

plt.arrow(-15,-9,-5,-5,color= "b")

plt.arrow(-20,-14,-10,10)

plt.arrow(-30,-4,5,10,color= "g")

# %%
x1 = -40
x2 = 40

y1= 40
y2 = -40

plt.axis([x1,x2,y2,y1])

plt.arrow(10.2,30,-20,1,head_length=0,head_width=0,color="#f3243c")

plt.arrow(10,30,-8,-20,color="b")
plt.arrow(2,10,20,5,color="g")

plt.arrow(22,15,-5,-20)

plt.arrow(17,-5,5,-10,color= "r")

plt.arrow(22,-15,-10,-10,color= "g")

plt.arrow(12,-25,-25,5,color= "b")

plt.arrow(-13,-20,8,8)

plt.arrow(-15,-9,10,-3,color= "g")

plt.arrow(-15,-9,-5,-5,color= "b")

plt.arrow(-20,-14,-10,10)

plt.arrow(-30,-4,5,10,color= "g")
plt.arrow(-25,6,-5,10,color= "b")

# %%
x1 = -40
x2 = 40

y1= 40
y2 = -40

plt.axis([x1,x2,y2,y1])

plt.arrow(10.2,30,-20,1,head_length=0,head_width=0,color="#f3243c")

plt.arrow(10,30,-8,-20,color="b")
plt.arrow(2,10,20,5,color="g")

plt.arrow(22,15,-5,-20)

plt.arrow(17,-5,5,-10,color= "r")

plt.arrow(22,-15,-10,-10,color= "g")

plt.arrow(12,-25,-25,5,color= "b")

plt.arrow(-13,-20,8,8)

plt.arrow(-15,-9,10,-3,color= "g")

plt.arrow(-15,-9,-5,-5,color= "b")

plt.arrow(-20,-14,-10,10)

plt.arrow(-30,-4,5,10,color= "g")
plt.arrow(-25,6,-5,10,color= "b")
plt.arrow(-30,16,18,2,color = "r")

# %%
x1 = -40
x2 = 40

y1= 40
y2 = -40

plt.axis([x1,x2,y2,y1])

plt.arrow(10.2,30,-20,1,head_length=0,head_width=0,color="#f3243c")
plt.arrow(10,30,-8,-20,color="b")
plt.arrow(2,10,20,5,color="g")
plt.arrow(22,15,-5,-20)
plt.arrow(17,-5,5,-10,color= "r")
plt.arrow(22,-15,-10,-10,color= "g")
plt.arrow(12,-25,-25,5,color= "b")
plt.arrow(-13,-20,8,8)
plt.arrow(-15,-9,10,-3,color= "g")
plt.arrow(-15,-9,-5,-5,color= "b")
plt.arrow(-20,-14,-10,10)
plt.arrow(-30,-4,5,10,color= "g")
plt.arrow(-25,6,-5,10,color= "b")
plt.arrow(-30,16,18,2,color = "r")
plt.arrow(-12,18,2.5,13)
plt.title("Figura")
# Out:
# Text(0.5, 1.0, 'Figura')

# %% [markdown]
# verificamos los vectores uno a uno, graficando como en animacion, donde cada uno trae los vectores anteriores y posteriormente el nuevo vector, asi sucesivamente, hasta llegar a la figura solicitada
